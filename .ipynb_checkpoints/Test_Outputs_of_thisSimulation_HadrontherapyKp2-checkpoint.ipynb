# %%
# !pwd
# Out:
# /Users/kpadhikari/KpInstalls/Geant4/ExamplesBld/HadronTherapyKp2

# %%
import pandas as pd
# https://stackoverflow.com/questions/44729498/plotting-data-from-multiple-pandas-data-frames-in-one-plot
import numpy as np
#https://stackoverflow.com/questions/45467320/plot-multiple-pandas-dataframes-in-one-graph
import matplotlib.pyplot as plt 

# https://github.com/jupyter/notebook/issues/3805 
#data = pd.read_csv('output_list.txt', header = None)
#pd.read_csv('file.csv', delimiter=' ')
#pd.read_csv('addresses.csv')
#pd.read_csv("whitespace.csv", header=None, delimiter=r"\s+")
dataframe = pd.read_csv("./Tmp/DoseV1.out",delim_whitespace=True) # works
#data = pd.read_csv('./TmpBkp_defMac/Dose.out', sep=" ", header=None) # doesn't work
#data = pd.read_csv('./TmpBkp_defMac/Dose.out', header=None, delimiter=r"\s+")  #works
df = dataframe
#print(dataframe)  #works (didn't want to print too much showing all rows)
df.head()
# Out:
#    i  j  k      Dose(Gy)
# 0  0  0  0  6.054910e-08
# 1  1  0  0  6.030820e-08
# 2  2  0  0  6.154180e-08
# 3  3  0  0  5.987870e-08
# 4  4  0  0  6.031540e-08

# %%
# %matplotlib inline
df.plot(y='Dose(Gy)', color="Green")

# %%
def plotDose(file):
    dfd = pd.read_csv(file,delim_whitespace=True) # works
    rcParams['figure.figsize'] = 7, 5 #kp: without this line, default figure size was too small
    dfd.plot(y='Dose(Gy)', color="Green")
    
plotDose("./Tmp/DoseV1.out")

# %%
df1 = pd.read_csv("./Dose.out",delim_whitespace=True) # works
#data = pd.read_csv('./TmpBkp_defMac/Dose.out', sep=" ", header=None) # doesn't work
#data = pd.read_csv('./TmpBkp_defMac/Dose.out', header=None, delimiter=r"\s+")  #works
#print(dataframe)  #works (didn't want to print too much showing all rows)
df1.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-140-21ae01883f87> in <module>
# ----> 1 df1 = pd.read_csv("./Dose.out",delim_whitespace=True) # works
#       2 #data = pd.read_csv('./TmpBkp_defMac/Dose.out', sep=" ", header=None) # doesn't work
#       3 #data = pd.read_csv('./TmpBkp_defMac/Dose.out', header=None, delimiter=r"\s+")  #works
#       4 #print(dataframe)  #works (didn't want to print too much showing all rows)
#       5 df1.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./Dose.out' does not exist: b'./Dose.out'

# %%
df1.plot(y='Dose(Gy)', color="Green")

# %%
#https://stackoverflow.com/questions/50559000/how-do-i-make-2-images-appear-side-by-side-in-jupyter-notebook-ipython
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

# %matplotlib inline

# read images
#img_A = mpimg.imread('\path\to\img_A.png')
img_A = mpimg.imread('https://octodex.github.com/images/bannekat.png')
img_B = mpimg.imread('https://octodex.github.com/images/bannekat.png')

# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8 #kp: without this line, default figure size was too small

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_A);
ax[1].imshow(img_B);

# %%
def plotDoseLET(file):
    dfd = pd.read_csv(file,delim_whitespace=True) # works
    #print(dfd.head())  #dfd.head()

    #rcParams['figure.figsize'] = 18 , 6 
    #fig5, (ax1, ax2, ax3) = plt.subplots(1,3)
    #ax1.plot(dfd["Dose"], color="Green")
    #ax2.plot(dfd["LDT"], color="Green")
    #ax3.plot(dfd["LTT"], color="Green")

    rcParams['figure.figsize'] = 12 , 12 #kp: without this line, default figure size was too small
    fig, axes = plt.subplots(2, 2)#, subplot_kw=dict(polar=True))

    axes[0, 0].plot(dfd["Dose"], color="Green")#, title="Dose")
    axes[0, 1].plot(dfd["LDT"], color="Blue")
    axes[1, 0].plot(dfd["LTT"], color="Red")
    axes[1, 1].plot(dfd["Dose"], color="Green")
    axes[1, 1].plot(dfd["LDT"], color="Blue")
    axes[1, 1].plot(dfd["LTT"], color="Red")
    
    axes[0, 0].title.set_text('Dose')
    axes[0, 1].title.set_text('LDT')
    axes[1, 0].title.set_text('LTT')
    axes[1, 1].title.set_text('All three')

plotDoseLET("./Let.out") #works.
#plotDoseLET("./LetDoseEtcBigStat.out")

# %%
#from matplotlib import rcParams

df2 = pd.read_csv("./Outputs/Let220.out",delim_whitespace=True) # works
#df2 = pd.read_csv("/Users/kpadhikari/KpInstalls/Geant4/ExamplesBld/HadronTherapyKp2/Outputs/Let200.out",delim_whitespace=True)
#df2 = pd.read_csv("./Outputs/Let200.out",delim_whitespace=True) # works
#df2 = pd.read_csv("./Outputs/Let180.out",delim_whitespace=True) # works
#data = pd.read_csv('./TmpBkp_defMac/Dose.out', sep=" ", header=None) # doesn't work
#data = pd.read_csv('./TmpBkp_defMac/Dose.out', header=None, delimiter=r"\s+")  #works
#print(dataframe)  #works (didn't want to print too much showing all rows)
df2.head()
#!pwd

# %%
# %matplotlib inline

rcParams['figure.figsize'] = 18 , 6 #kp: without this line, default figure size was too small

fig5, (ax1, ax2, ax3) = plt.subplots(1,3)

ax1.plot(df2["Dose"], color="Green")
ax2.plot(df2["LDT"], color="Green")
ax3.plot(df2["LTT"], color="Green")

# %%
df2.plot(y='LDT', color="Green")

# %%
df2.plot(y='LTT', color="Green")

# %%
dfd = pd.read_csv("./Outputs/Dose180.out",delim_whitespace=True) # works
print(dfd.head())

rcParams['figure.figsize'] = 6 , 6 
dfd.plot(y='Dose(Gy)', color="Green")

# %%
dfd = pd.read_csv("./Outputs/Let215.out",delim_whitespace=True) # works
print(dfd.head())

#rcParams['figure.figsize'] = 18 , 6 
#fig5, (ax1, ax2, ax3) = plt.subplots(1,3)
#ax1.plot(dfd["Dose"], color="Green")
#ax2.plot(dfd["LDT"], color="Green")
#ax3.plot(dfd["LTT"], color="Green")

rcParams['figure.figsize'] = 16 , 16 #kp: without this line, default figure size was too small
fig, axes = plt.subplots(2, 2)#, subplot_kw=dict(polar=True))

axes[0, 0].plot(dfd["Dose"], color="Green")
axes[0, 1].plot(dfd["LDT"], color="Blue")
axes[1, 0].plot(dfd["LTT"], color="Red")
axes[1, 1].plot(dfd["Dose"], color="Green")
axes[1, 1].plot(dfd["LDT"], color="Blue")
axes[1, 1].plot(dfd["LTT"], color="Red")

# %%
def wk0(n, p):
    base = (1 - 1/(2*n))
    exponent = (1 - 1/p)
    return (1 - pow( base, exponent))

def wkg(n, p, k):
    exponent = (1 - 1/p)
    base1 = 1 - (k - 1/2)/n
    base2 = 1 - (k + 1/2)/n
    return (pow(base1, exponent) - pow(base2, exponent))
            
def wkn(n, p):
    exponent = (1 - 1/p)
    return pow(1/(2*n), exponent)

# %%
n = 10 #9
#p = 2.2 #1.9
p = 1.77
#p = 1.6 #1.425
wt2 = [wk0(n,p), wkg(n,p,1), wkg(n,p,2), wkg(n,p,3), wkg(n,p,4), 
       wkg(n,p,5), wkg(n,p,6), wkg(n,p,7), wkg(n,p,8), wkg(n,p,9), 
       wkn(n,p)]
print(wt2)


dfArr = []
dfWtArr = []
file = ""

#while (i < 9):  #works but needs the incrementer line i = i+1
for i in range(0,n+1): #11):
    #print(i)
    file = "./Outputs/Dose{}.out".format(170 + i*5)
    #file = "./Outputs/Let{}.out".format(170 + i*5)
    df = pd.read_csv(file,delim_whitespace=True)
    dfArr.append(df)
    dfWtArr.append(wt2[i]*df)
    #print(dfArr[i])
    print("Appended dataframe of " + file + " to the dataframe Dict.")
    

rcParams['figure.figsize'] = 16 , 16 #kp: without this line, default figure size was too small

#fig, axes = plt.subplots(2, 2, subplot_kw=dict(polar=True))
fig, axes = plt.subplots(2, 2)#, subplot_kw=dict(polar=True))

colName = "Dose(Gy)" # Only for Dose???.out file
#colName = "Dose"
#colName = "LDT"
#colName = "LTT"

for i in range(0,n+1):
    axes[0, 0].plot(dfArr[i][colName])
    axes[0, 1].plot(wt2[i]*dfArr[i][colName])

#frames180to220 = [df180, df185, df190, df195, df200, df205, df210, df215, df220]
#resSum180to220 = pd.concat(frames180to220).groupby(level=0).sum()
sum180to220 = pd.concat(dfArr).groupby(level=0).sum()
sum180to220wt = pd.concat(dfWtArr).groupby(level=0).sum()

#axes[1, 1].scatter(x, y)
axes[1, 0].plot(sum180to220[colName], color="Green")
axes[1, 1].plot(sum180to220wt[colName], color="Green")

# %%
rcParams['figure.figsize'] = 16 , 8 #kp: without this line, default figure size was too small

f5, (ax1, ax2) = plt.subplots(1,2)
for i in range(0,n+1):
    #ax1.plot(dfArr[i]["Dose"])
    #ax2.plot(wt2[i]*dfArr[i]["Dose"])
    ax1.plot(dfArr[i]["Dose(Gy)"])
    ax2.plot(wt2[i]*dfArr[i]["Dose(Gy)"])

# %%
#frames180to220 = [df180, df185, df190, df195, df200, df205, df210, df215, df220]
#resSum180to220 = pd.concat(frames180to220).groupby(level=0).sum()
sum180to220 = pd.concat(dfArr).groupby(level=0).sum()
sum180to220wt = pd.concat(dfWtArr).groupby(level=0).sum()

rcParams['figure.figsize'] = 16 , 8 #kp: without this line, default figure size was too small

fig5, (ax1, ax2) = plt.subplots(1,2)
#ax[0].imshow(pd.concat(framesN1wtd1).groupby(level=0).sum());
#ax2.imshow(resSumN1wtd1.plot(y='Dose', color="Green"));
#ax1.plot(sum180to220["Dose"], color="Green")
#ax2.plot(sum180to220wt["Dose"], color="Green")
ax1.plot(sum180to220["Dose(Gy)"], color="Green")
ax2.plot(sum180to220wt["Dose(Gy)"], color="Green")

# %%
plotDoseLET("./Results/Let205.0MeV.out")

# %%
plotDoseLET("./Let.out")

# %%
plotDose("./Results/Dose205.0MeV.out")

# %%
n = 15 #9
#p = 2.2 #1.9
#p = 1.77
p = 1.73 #1.425
"""
wt2 = [wk0(n,p), wkg(n,p,1), wkg(n,p,2), wkg(n,p,3), wkg(n,p,4), 
       wkg(n,p,5), wkg(n,p,6), wkg(n,p,7), wkg(n,p,8), wkg(n,p,9), 
       wkg(n,p,10), wkg(n,p,11), wkg(n,p,12), wkg(n,p,13), wkg(n,p,14), 
       wkn(n,p)]
"""
#Starting the weight list with the one for the first pure Bragg peak
wt2 = [wk0(n,p)] # list of weights, more will be appended in a loop

# Appending all the others except the last one.
for i in range (1,n):
    wt2.append(wkg(n,p,i))
    
wt2.append(wkn(n,p)) # Weight for the last pristine Bragg peak

print(wt2)

Ei = 170
dE = 2

dfArr = []
dfWtArr = []
dir = "./Results/V1_10kEvs/"
file = ""

#while (i < 9):  #works but needs the incrementer line i = i+1
for i in range(0,n+1): #11):
    #print(i)
    #file = "./Results/V1_10kEvs/Let_gpsPr{}.00MeV.out".format(Ei + i*dE)
    file = dir + "Let_gpsPr{}.00MeV.out".format(Ei + i*dE)
    #file = "./Outputs/Let{}.out".format(170 + i*5)
    df = pd.read_csv(file,delim_whitespace=True)
    dfArr.append(df)
    dfWtArr.append(wt2[i]*df)
    #print(dfArr[i])
    print("Appended dataframe of " + file + " to the dataframe Dict.")
    

rcParams['figure.figsize'] = 16 , 16 #kp: without this line, default figure size was too small

#fig, axes = plt.subplots(2, 2, subplot_kw=dict(polar=True))
fig, axes = plt.subplots(2, 2)#, subplot_kw=dict(polar=True))

#colName = "Dose(Gy)" # Only for Dose???.out file
colName = "Dose"
#colName = "LDT"
#colName = "LTT"

for i in range(0,n+1):
    axes[0, 0].plot(dfArr[i][colName])
    axes[0, 1].plot(wt2[i]*dfArr[i][colName])

#frames180to220 = [df180, df185, df190, df195, df200, df205, df210, df215, df220]
#resSum180to220 = pd.concat(frames180to220).groupby(level=0).sum()
sum180to220 = pd.concat(dfArr).groupby(level=0).sum()
sum180to220wt = pd.concat(dfWtArr).groupby(level=0).sum()

#axes[1, 1].scatter(x, y)
axes[1, 0].plot(sum180to220[colName], color="Green")
axes[1, 1].plot(sum180to220wt[colName], color="Green")

# %%
type(wt2)

# %% [markdown]
# ### Now plotting LDT and LTT corresponding to above SOBP

# %%
rcParams['figure.figsize'] = 16 , 16 #kp: without this line, default figure size was too small
fig, axes = plt.subplots(2, 2)#, subplot_kw=dict(polar=True))

#colName = "Dose(Gy)" # Only for Dose???.out file
#colName = "Dose"
#colName = "LDT"
#colName = "LTT"

#axes[1, 1].scatter(x, y)
axes[0, 0].plot(sum180to220["LDT"], color="Green")
axes[0, 1].plot(sum180to220wt["LDT"], color="Green")
axes[1, 0].plot(sum180to220["LTT"], color="Green")
axes[1, 1].plot(sum180to220wt["LTT"], color="Green")

# %%
# whichPlots: 0, 1
#     if 0: plot scaled and unscaled individuals on the first two plots and combined ones in the next two
#     if 1: plot scaled "Dose", "LDT" and "LTT"
def plotSOBP(dataDirectory, nBeams, initEb, stepEb, pExp, verbosity, whichPlots):
    """
    =======
    This formula is from the following paper:
     "Creating a spread-out Bragg peak in proton beams" by David Jette and Weimin Chen
     ======
    
    The model of Bortfeld and Schlegel (1996 Phys. Med. Biol. 41 1331–9) for
    determining the weights of proton beams required to create a spread-out Bragg
    peak (SOBP) ....
    
    The work is based on a close power-law relationship between the range R of 
    protons and their energy E:
        R = αE^{p0} , (1)
    where α = 0.0022 and p0 = 1.77. The values of these two parameters are properly taken from
    a subsequent study (Bortfeld 1997) which develops analytic incorporation of range straggling
    into the Bragg curve.
    
    The SOBP is divided into n equal intervals, and monoenergetic beams of range equal to 
    the depth of the ends of these intervals are used, with weights given by wk for 
    k = 0, 1, . . . , n. 
    """
    #n = 10 #15 #9
    n = nBeams - 1  # Number of divisions of SOBP = One less than the # of pristine peaks or Ebeams
    
    #p = 1.73 #1.77 #1.425 #2.2 #1.9
    p = pExp
    
    ######### Next creating the list of weights ############
    """
    # Following is what I used to do for n = 10 (without using loop)
    wt = [wk0(n,p), wkg(n,p,1), wkg(n,p,2), wkg(n,p,3), wkg(n,p,4), 
           wkg(n,p,5), wkg(n,p,6), wkg(n,p,7), wkg(n,p,8), wkg(n,p,9), 
           wkn(n,p)]
    """ 
    #Starting the weight list with the one for the first pure Bragg peak
    wt = [wk0(n,p)] # list of weights, more will be appended in a loop

    # Appending all the others except the last one.
    for i in range (1,n):
        wt.append(wkg(n,p,i))
    
    wt.append(wkn(n,p)) # Weight for the last pristine Bragg peak

    if verbosity == True:
        print(wt)
    #######################

    Ei = initEb #170
    dE = stepEb #2
    dfArr = []
    dfWtArr = []
    file = ""

    #while (i < 9):  #works but needs the incrementer line i = i+1
    for i in range(0,nBeams): #11):
        #print(i)
        #file = "./Results/V1_10kEvs/Let_gpsPr{}.00MeV.out".format(Ei + i*dE)
        file = dataDirectory + "Let_gpsPr{}.00MeV.out".format(initEb + i*stepEb)
        df = pd.read_csv(file,delim_whitespace=True)
        dfArr.append(df)
        dfWtArr.append(wt[i]*df)
        if verbosity == True:
            #print(dfArr[i])
            print("Appended dataframe of " + file + " to the dataframe Dict.")

    #frames180to220 = [df180, df185, df190, df195, df200, df205, df210, df215, df220]
    #resSum180to220 = pd.concat(frames180to220).groupby(level=0).sum()
    ######kp: We get "FutureWarning" without sort=True below
    simpleSum = pd.concat(dfArr, sort=True).groupby(level=0).sum()
    weightedSum = pd.concat(dfWtArr, sort=True).groupby(level=0).sum()
        
    ################# Now lets draw the plots #########
    if whichPlots == 0:
        rcParams['figure.figsize'] = 16 , 16 #kp: without this line, default figure size was too small

        #fig, axes = plt.subplots(2, 2, subplot_kw=dict(polar=True))
        fig, axes = plt.subplots(2, 2)#, subplot_kw=dict(polar=True))

        #colName = "Dose(Gy)" # Only for Dose???.out file
        colName = "Dose"
        #colName = "LDT"
        #colName = "LTT"
        for i in range(0,nBeams):
            axes[0, 0].plot(dfArr[i][colName])
            axes[0, 1].plot(wt[i]*dfArr[i][colName])


        #axes[1, 1].scatter(x, y)
        axes[1, 0].plot(simpleSum[colName], color="Green")
        axes[1, 1].plot(weightedSum[colName], color="Green")
        axes[0, 0].title.set_text('Dose (Pristine Peaks - unscaled)')
        axes[0, 1].title.set_text('Dose (Pristine Peaks - scaled)')
        axes[1, 0].title.set_text('Unweighted Sum')
        axes[1, 1].title.set_text('SOBP - weighted sum')
    else:
        rcParams['figure.figsize'] = 18 , 6 #kp: without this line, default figure size was too small
        fig, (axes1, axes2, axes3) = plt.subplots(1, 3)#, subplot_kw=dict(polar=True))
        #"""
        axes1.plot(weightedSum["Dose"], color="Green")
        axes2.plot(weightedSum["LDT"], color="Green")
        axes3.plot(weightedSum["LTT"], color="Green")
        axes1.title.set_text('SOBP - weighted sum')
        axes2.title.set_text('LDT (keV/um) corresponding to SOBP')
        axes3.title.set_text('LTT (keV/um) corresponding to SOBP')
        #"""

# %%
#plotSOBP("./Results/V1_10kEvs/", 10, 170, 2, 1.75, 0)
#plotSOBP("./Results/V1_10kEvs/", 25, 170, 2, 1.73, 0)
plotSOBP("./Results/V1_50kEvs/", 25, 170, 2, 1.73, True, 0) #verbosity == True prints wt values and filenames
# Out:
# [0.008844464074329816, 0.018021078268537938, 0.018490247494291512, 0.018994344424651644, 0.019537828664106804, 0.020125991538739174, 0.020765165554653575, 0.021463001896723677, 0.02222884365637967, 0.02307423632101757, 0.024013639294836686, 0.025065438969934628, 0.026253426581243522, 0.027609015104521628, 0.029174674498117725, 0.03100946241270386, 0.03319834579446257, 0.03586881483373361, 0.03922263839487905, 0.04360229788625836, 0.049648007003404104, 0.058740385739882606, 0.07466193362415924, 0.11514415197730346, 0.19524256599112744]
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr170.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr172.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr174.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr176.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr178.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr180.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr182.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr184.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr186.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr188.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr190.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr192.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr194.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr196.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr198.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr200.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr202.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr204.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr206.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr208.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr210.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr212.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr214.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr216.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_50kEvs/Let_gpsPr218.00MeV.out to the dataframe Dict.

# %%
plotSOBP("./Results/V1_100kEvs/", 45, 170, 2, 1.68, False, 0)

# %%
plotSOBP("./Results/V1_100kEvs/", 25, 210, 2, 1.73, False, 0)

# %%
plotSOBP("./Results/V1_10kEvs/", 25, 170, 2, 1.73, True, 1)
# Out:
# [0.008844464074329816, 0.018021078268537938, 0.018490247494291512, 0.018994344424651644, 0.019537828664106804, 0.020125991538739174, 0.020765165554653575, 0.021463001896723677, 0.02222884365637967, 0.02307423632101757, 0.024013639294836686, 0.025065438969934628, 0.026253426581243522, 0.027609015104521628, 0.029174674498117725, 0.03100946241270386, 0.03319834579446257, 0.03586881483373361, 0.03922263839487905, 0.04360229788625836, 0.049648007003404104, 0.058740385739882606, 0.07466193362415924, 0.11514415197730346, 0.19524256599112744]
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr170.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr172.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr174.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr176.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr178.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr180.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr182.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr184.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr186.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr188.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr190.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr192.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr194.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr196.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr198.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr200.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr202.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr204.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr206.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr208.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr210.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr212.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr214.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr216.00MeV.out to the dataframe Dict.
# Appended dataframe of ./Results/V1_10kEvs/Let_gpsPr218.00MeV.out to the dataframe Dict.

# %%
plotSOBP("./Results/V1_50kEvs/", 25, 170, 2, 1.73, False, 1)

# %%
plotSOBP("./Results/V1_100kEvs/", 25, 170, 2, 1.73, False, 1)
